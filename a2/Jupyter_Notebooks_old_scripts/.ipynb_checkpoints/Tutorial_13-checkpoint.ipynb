# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from scipy.spatial import Voronoi, voronoi_plot_2d, Delaunay
from importlib import reload

# %%
np.random.seed(42)
N = 10
points = np.random.random((N,2))
vor = Voronoi(points,incremental=True)
voronoi_plot_2d(vor)
plt.show()
tri = Delaunay(points,incremental=True)
plt.triplot(points[:,0],points[:,1],tri.simplices.copy())
plt.plot(points[:,0],points[:,1],'o')
plt.show()

# %%
np.random.seed(42)
N = 20
points = np.random.random((N,2))
vor = Voronoi(points,incremental=True)
voronoi_plot_2d(vor)
plt.show()
tri = Delaunay(points,incremental=True)
plt.triplot(points[:,0],points[:,1],tri.simplices.copy())
plt.plot(points[:,0],points[:,1],'o')
plt.show()

# %%
np.random.seed(42)
N = 40
points = np.random.random((N,2))
vor = Voronoi(points,incremental=True)
voronoi_plot_2d(vor)
plt.show()
tri = Delaunay(points,incremental=True)
plt.triplot(points[:,0],points[:,1],tri.simplices.copy())
plt.plot(points[:,0],points[:,1],'o')
plt.show()

# %% [markdown]
# #### What is the relation between the Voronoi tesselation and Delaunay triangulation?
#
# Ding met die circles.

# %%
np.random.seed(41)
N = 40
points = np.random.randn(N,2)
vor = Voronoi(points,incremental=True)
voronoi_plot_2d(vor)
plt.show()
tri = Delaunay(points,incremental=True)
plt.triplot(points[:,0],points[:,1],tri.simplices.copy())
plt.plot(points[:,0],points[:,1],'o')
plt.show()

# %%
import h5py
filename = 'lowres512.hdf5'
f = h5py.File(filename,'r')
#print(list(f.keys()))
a_group_key = list(f.keys())[1]
data_type0 = f['PartType0']['Coordinates']
data_type0 = data_type0[:,:2]
data_type4 = f['PartType4']['Coordinates']
data_type4 = data_type4[:,:2]

# %%
plt.scatter(data_type4[:,0],data_type4[:,1],marker='.')
plt.show()
plt.scatter(data_type0[:,0],data_type0[:,1],marker='.')
plt.show()

# %%
import NR_a2_7_all as utils7

# %%
np.random.seed(42)
data = (np.random.normal(size=(150,150)))
plt.scatter(data[0],data[1])

# %%
reload(utils7)
t = utils7.Tree(12,data_type4)
p = t.get_points()
t.root.children[0].center
print(len(t.root.children))
t.graph()
# Out:
# 4
# 349
# Number of segments: 349
# Minimum segment area: 0.0027726365334256003 units

# %%
reload(utils7)
t = utils7.Tree(12,data_type0)
p = t.get_points()
#t.root.children[0].center
#print(len(t.root.children))
t.graph()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a04d01ec4855> in <module>()
# ----> 1 reload(utils7)
#       2 t = utils7.Tree(12,data_type0)
#       3 p = t.get_points()
#       4 #t.root.children[0].center
#       5 #print(len(t.root.children))
#
# NameError: name 'reload' is not defined
